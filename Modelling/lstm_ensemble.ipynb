# %% [markdown]
# # LSTM Model -- Walk-Forward Evaluation
#
# This notebook builds and evaluates the LSTM secondary model as a standalone predictor:
#
# 1. **Data preparation** -- merge price + NLP features, create sequences with 15-day lookback
# 2. **Dual MinMaxScalers** -- separate scalers for features and target (from SOTA)
# 3. **LSTM model** -- 2-layer, 64 units, orthogonal init, dropout, early stopping, jitter augmentation
# 4. **Walk-forward validation** -- expanding window, per-ticker batching, verbose progress
# 5. **Results** -- standalone LSTM vs naive baseline, per-ticker breakdown
# 6. **Save predictions** -- export to disk for the ensemble notebook
#
# **Input:** `features_price.csv`, `features_nlp.csv`
# **Output:** `lstm_predictions.pkl`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings

warnings.filterwarnings('ignore')
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['figure.dpi'] = 100

DATA_DIR = '..'
RANDOM_STATE = 42
TRAIN_PCT = 0.6
DEVICE = 'mps' if torch.backends.mps.is_available() else ('cuda' if torch.cuda.is_available() else 'cpu')

np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)

print(f'Device: {DEVICE}')
# Out:
# Device: mps

# %% [markdown]
# ## 1. Load and Merge Features

# %%
price_features = pd.read_csv(f'../features_price.csv', parse_dates=['date'])
nlp_features = pd.read_csv(f'../features_nlp.csv', parse_dates=['date'])

df = price_features.merge(nlp_features, on=['date', 'ticker'], how='left')
df = df.sort_values(['ticker', 'date']).reset_index(drop=True)

nlp_cols = [c for c in nlp_features.columns if c not in ['date', 'ticker']]
for col in nlp_cols:
    if col == 'has_news':
        df[col] = df[col].fillna(0).astype(int)
    else:
        df[col] = df[col].fillna(0.0)

df = df.dropna(subset=['target_next_close']).reset_index(drop=True)

tickers = sorted(df['ticker'].unique())

META_COLS = ['date', 'ticker']
TARGET_COLS = ['target_next_close', 'target_next_return', 'target_direction']
OHLCV_COLS = ['open', 'high', 'low', 'close', 'volume']
EXCLUDE_COLS = META_COLS + TARGET_COLS + ['is_outlier']

price_feature_cols = [c for c in price_features.columns if c not in EXCLUDE_COLS + OHLCV_COLS]
nlp_feature_cols = list(nlp_cols)
all_feature_cols = price_feature_cols + nlp_feature_cols

print(f'Merged shape: {df.shape}')
print(f'Total features: {len(all_feature_cols)}')
print(f'Tickers: {tickers}')
# Out:
# Merged shape: (1449, 82)
# Total features: 71
# Tickers: ['AAPL', 'AMZN', 'GOOGL', 'META', 'MSFT', 'NVDA', 'TSLA']

# %% [markdown]
# ## 2. Sequence Creation and Dataset

# %%
LOOKBACK = 15
JITTER_STD = 0.01


class StockSequenceDataset(Dataset):
    def __init__(self, X_seq, y_seq, jitter=False, jitter_std=0.01):
        self.X = torch.FloatTensor(X_seq)
        self.y = torch.FloatTensor(y_seq)
        self.jitter = jitter
        self.jitter_std = jitter_std

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        if self.jitter:
            x = x + torch.randn_like(x) * self.jitter_std
        return x, self.y[idx]


def create_sequences(features, targets, lookback):
    """Create overlapping sequences of length `lookback` from scaled feature/target arrays."""
    X_seq, y_seq = [], []
    for i in range(lookback, len(features)):
        X_seq.append(features[i - lookback:i])
        y_seq.append(targets[i])
    return np.array(X_seq), np.array(y_seq)


print(f'Lookback window: {LOOKBACK} days')
print(f'Jitter augmentation std: {JITTER_STD}')
# Out:
# Lookback window: 15 days
# Jitter augmentation std: 0.01

# %% [markdown]
# ## 3. LSTM Model Definition

# %%
class StockLSTM(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, dropout=0.2):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0
        )
        self.fc = nn.Sequential(
            nn.Linear(hidden_size, 32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(32, 1)
        )
        self._init_weights()

    def _init_weights(self):
        for name, param in self.lstm.named_parameters():
            if 'weight_ih_l0' in name:
                nn.init.orthogonal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
            elif 'bias' in name:
                nn.init.zeros_(param)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        last_hidden = lstm_out[:, -1, :]
        return self.fc(last_hidden).squeeze(-1)


print(f'Model architecture: LSTM(2 layers, 64 units) -> Dense(32) -> Dense(1)')
print(f'Initialization: orthogonal (first layer weights, from SOTA Notebook 5)')
# Out:
# Model architecture: LSTM(2 layers, 64 units) -> Dense(32) -> Dense(1)
# Initialization: orthogonal (first layer weights, from SOTA Notebook 5)

# %% [markdown]
# ## 4. Training Function with Early Stopping

# %%
def train_lstm(model, train_loader, val_X, val_y, device,
               epochs=150, lr=5e-4, patience=15, verbose=True):
    """Train LSTM with early stopping on validation loss."""
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=5
    )

    model.to(device)
    val_X_tensor = torch.FloatTensor(val_X).to(device)
    val_y_tensor = torch.FloatTensor(val_y).to(device)

    best_val_loss = float('inf')
    best_state = None
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        train_losses = []
        for batch_X, batch_y in train_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            optimizer.zero_grad()
            preds = model(batch_X)
            loss = criterion(preds, batch_y)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_losses.append(loss.item())

        model.eval()
        with torch.no_grad():
            val_preds = model(val_X_tensor)
            val_loss = criterion(val_preds, val_y_tensor).item()

        scheduler.step(val_loss)

        improved = ''
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            patience_counter = 0
            improved = ' *'
        else:
            patience_counter += 1

        if verbose and (epoch % 10 == 0 or patience_counter >= patience or epoch == epochs - 1):
            avg_train = np.mean(train_losses)
            print(f'    Epoch {epoch+1:>3}/{epochs}  train_loss={avg_train:.6f}  '
                  f'val_loss={val_loss:.6f}  patience={patience_counter}/{patience}{improved}')

        if patience_counter >= patience:
            if verbose:
                print(f'    Early stopping at epoch {epoch+1}')
            break

    model.load_state_dict(best_state)
    return model, epoch + 1, best_val_loss


print('Training function ready (Adam, lr=5e-4, patience=15, grad clipping=1.0)')
# Out:
# Training function ready (Adam, lr=5e-4, patience=15, grad clipping=1.0)

# %% [markdown]
# ## 5. Walk-Forward LSTM Evaluation (Standalone)
#
# Same expanding window as the XGBoost notebook:
# - Initial training: `TRAIN_PCT` of data
# - Step forward 5 days at a time
# - At each step: scale data with dual scalers, create sequences, train LSTM, predict
# - Progress printed every 10 epochs per step

# %%
def compute_metrics(actual, predicted):
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mae = mean_absolute_error(actual, predicted)
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    actual_dir = np.diff(actual) > 0
    pred_dir = np.diff(predicted) > 0
    dir_acc = np.mean(actual_dir == pred_dir) * 100 if len(actual_dir) > 0 else 0.0
    return {'RMSE': rmse, 'MAE': mae, 'MAPE': mape, 'Dir_Acc': dir_acc}

# %%
INITIAL_TRAIN_PCT = TRAIN_PCT
STEP_SIZE = 5
HIDDEN_SIZE = 64
NUM_LAYERS = 2
DROPOUT = 0.2
BATCH_SIZE = 16
EPOCHS = 150
PATIENCE = 15

lstm_results = {}

for ticker in tickers:
    print(f'\n{"=" * 60}')
    print(f'  LSTM Walk-Forward: {ticker}')
    print(f'{"=" * 60}')

    sub = df[df['ticker'] == ticker].copy().reset_index(drop=True)
    n = len(sub)
    initial_train_size = int(n * INITIAL_TRAIN_PCT)

    dates_all = sub['date'].values
    features_raw = sub[all_feature_cols].values
    target_raw = sub['target_next_close'].values
    close_raw = sub['close'].values

    lstm_predictions = []
    naive_predictions = []
    actuals = []
    pred_dates = []

    train_end = initial_train_size
    step_num = 0

    while train_end < n:
        predict_end = min(train_end + STEP_SIZE, n)
        step_num += 1

        # --- Dual scalers (fit on training data only) ---
        feature_scaler = MinMaxScaler(feature_range=(-1, 1))
        target_scaler = MinMaxScaler(feature_range=(-1, 1))

        feature_scaler.fit(features_raw[:train_end])
        target_scaler.fit(target_raw[:train_end].reshape(-1, 1))

        features_all_scaled = feature_scaler.transform(features_raw[:predict_end])
        target_all_scaled = target_scaler.transform(target_raw[:predict_end].reshape(-1, 1)).flatten()

        # --- Create sequences ---
        X_seq_all, y_seq_all = create_sequences(features_all_scaled, target_all_scaled, LOOKBACK)

        seq_train_end = train_end - LOOKBACK
        if seq_train_end < 20:
            train_end = predict_end
            continue

        val_size = max(int(seq_train_end * 0.2), 5)
        lstm_train_end = seq_train_end - val_size

        X_train_seq = X_seq_all[:lstm_train_end]
        y_train_seq = y_seq_all[:lstm_train_end]
        X_val_seq = X_seq_all[lstm_train_end:seq_train_end]
        y_val_seq = y_seq_all[lstm_train_end:seq_train_end]
        X_test_seq = X_seq_all[seq_train_end:predict_end - LOOKBACK]

        if len(X_test_seq) == 0 or len(X_train_seq) < 20:
            train_end = predict_end
            continue

        print(f'\n  Step {step_num} (train_end={train_end}, train_seqs={len(X_train_seq)}, '
              f'val_seqs={len(X_val_seq)}, test_seqs={len(X_test_seq)})')

        # --- Train LSTM ---
        train_dataset = StockSequenceDataset(X_train_seq, y_train_seq, jitter=True, jitter_std=JITTER_STD)
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

        model = StockLSTM(
            input_size=len(all_feature_cols),
            hidden_size=HIDDEN_SIZE,
            num_layers=NUM_LAYERS,
            dropout=DROPOUT
        )

        model, stopped_epoch, best_val = train_lstm(
            model, train_loader, X_val_seq, y_val_seq, DEVICE,
            epochs=EPOCHS, patience=PATIENCE, verbose=True
        )

        # --- LSTM predictions ---
        model.eval()
        model.to(DEVICE)
        with torch.no_grad():
            X_test_tensor = torch.FloatTensor(X_test_seq).to(DEVICE)
            lstm_preds_scaled = model(X_test_tensor).cpu().numpy()

        lstm_preds = target_scaler.inverse_transform(lstm_preds_scaled.reshape(-1, 1)).flatten()

        # --- Align with original data ---
        test_start_orig = train_end
        num_preds = min(len(lstm_preds), n - test_start_orig)
        lstm_preds = lstm_preds[:num_preds]

        test_actuals = target_raw[test_start_orig:test_start_orig + num_preds]
        test_naive = close_raw[test_start_orig:test_start_orig + num_preds]
        test_dates_slice = dates_all[test_start_orig:test_start_orig + num_preds]

        lstm_predictions.extend(lstm_preds.tolist())
        naive_predictions.extend(test_naive.tolist())
        actuals.extend(test_actuals.tolist())
        pred_dates.extend(test_dates_slice.tolist())

        print(f'  -> Predicted {num_preds} days (stopped epoch {stopped_epoch}, best_val={best_val:.6f})')

        del model, train_dataset, train_loader, X_test_tensor, lstm_preds_scaled
        if DEVICE == 'mps':
            torch.mps.empty_cache()

        train_end = predict_end

    # --- Store LSTM-only results ---
    actuals_arr = np.array(actuals)
    lstm_arr = np.array(lstm_predictions)
    naive_arr = np.array(naive_predictions)

    lstm_results[ticker] = {
        'dates': pred_dates,
        'actuals': actuals_arr,
        'naive': naive_arr,
        'lstm': lstm_arr,
        'metrics_naive': compute_metrics(actuals_arr, naive_arr),
        'metrics_lstm': compute_metrics(actuals_arr, lstm_arr),
    }

    print(f'\n  {ticker} LSTM Results:')
    for name in ['metrics_naive', 'metrics_lstm']:
        m = lstm_results[ticker][name]
        label = name.replace('metrics_', '').upper()
        print(f'    {label:<10} RMSE={m["RMSE"]:.2f}  MAE={m["MAE"]:.2f}  '
              f'MAPE={m["MAPE"]:.2f}%  Dir_Acc={m["Dir_Acc"]:.1f}%')

import gc
if DEVICE == 'mps':
    torch.mps.empty_cache()
elif DEVICE == 'cuda':
    torch.cuda.empty_cache()
gc.collect()

print('\n' + '=' * 60)
print('LSTM walk-forward completed for all tickers.')
print('GPU/MPS memory cleared.')
# Out:
# ============================================================
#   LSTM Walk-Forward: AAPL
# ============================================================
#
#   Step 1 (train_end=124, train_seqs=88, val_seqs=21, test_seqs=5)
#     Epoch   1/150  train_loss=0.388679  val_loss=0.380956  patience=0/15 *
#     Epoch  11/150  train_loss=0.033382  val_loss=0.397174  patience=10/15
#     Epoch  16/150  train_loss=0.015231  val_loss=0.409793  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.380956)
#
#   Step 2 (train_end=129, train_seqs=92, val_seqs=22, test_seqs=5)
#     Epoch   1/150  train_loss=0.159021  val_loss=0.552263  patience=0/15 *
#     Epoch  11/150  train_loss=0.016371  val_loss=0.545927  patience=6/15
#     Epoch  20/150  train_loss=0.013023  val_loss=0.542585  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 5 days (stopped epoch 20, best_val=0.530311)
#
#   Step 3 (train_end=134, train_seqs=96, val_seqs=23, test_seqs=5)
#     Epoch   1/150  train_loss=0.490891  val_loss=0.250552  patience=0/15 *
#     Epoch  11/150  train_loss=0.027361  val_loss=0.301461  patience=10/15
#     Epoch  16/150  train_loss=0.022023  val_loss=0.307749  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.250552)
#
#   Step 4 (train_end=139, train_seqs=100, val_seqs=24, test_seqs=5)
#     Epoch   1/150  train_loss=0.329516  val_loss=0.441936  patience=0/15 *
#     Epoch  11/150  train_loss=0.023586  val_loss=0.473477  patience=10/15
#     Epoch  16/150  train_loss=0.019271  val_loss=0.472216  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.441936)
#
#   Step 5 (train_end=144, train_seqs=104, val_seqs=25, test_seqs=5)
#     Epoch   1/150  train_loss=0.335059  val_loss=0.483192  patience=0/15 *
#     Epoch  11/150  train_loss=0.026224  val_loss=0.497233  patience=5/15
#     Epoch  21/150  train_loss=0.014115  val_loss=0.501460  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 5 days (stopped epoch 21, best_val=0.477722)
#
#   Step 6 (train_end=149, train_seqs=108, val_seqs=26, test_seqs=5)
#     Epoch   1/150  train_loss=0.301440  val_loss=0.530460  patience=0/15 *
#     Epoch  11/150  train_loss=0.020678  val_loss=0.444808  patience=0/15 *
#     Epoch  21/150  train_loss=0.016696  val_loss=0.424805  patience=7/15
#     Epoch  29/150  train_loss=0.011469  val_loss=0.428260  patience=15/15
#     Early stopping at epoch 29
#   -> Predicted 5 days (stopped epoch 29, best_val=0.417048)
#
#   Step 7 (train_end=154, train_seqs=112, val_seqs=27, test_seqs=5)
#     Epoch   1/150  train_loss=0.279060  val_loss=0.538673  patience=0/15 *
#     Epoch  11/150  train_loss=0.022565  val_loss=0.366521  patience=0/15 *
#     Epoch  21/150  train_loss=0.013808  val_loss=0.357712  patience=1/15
#     Epoch  31/150  train_loss=0.013851  val_loss=0.334039  patience=7/15
#     Epoch  39/150  train_loss=0.011167  val_loss=0.331017  patience=15/15
#     Early stopping at epoch 39
#   -> Predicted 5 days (stopped epoch 39, best_val=0.326469)
#
#   Step 8 (train_end=159, train_seqs=116, val_seqs=28, test_seqs=5)
#     Epoch   1/150  train_loss=0.219866  val_loss=0.670539  patience=0/15 *
#     Epoch  11/150  train_loss=0.024894  val_loss=0.467436  patience=2/15
#     Epoch  21/150  train_loss=0.014309  val_loss=0.406242  patience=0/15 *
#     Epoch  31/150  train_loss=0.012525  val_loss=0.428963  patience=2/15
#     Epoch  41/150  train_loss=0.013938  val_loss=0.395551  patience=1/15
#     Epoch  51/150  train_loss=0.009978  val_loss=0.386533  patience=5/15
#     Epoch  61/150  train_loss=0.009931  val_loss=0.368049  patience=0/15 *
#     Epoch  71/150  train_loss=0.008502  val_loss=0.375686  patience=10/15
#     Epoch  76/150  train_loss=0.011357  val_loss=0.380425  patience=15/15
#     Early stopping at epoch 76
#   -> Predicted 5 days (stopped epoch 76, best_val=0.368049)
#
#   Step 9 (train_end=164, train_seqs=120, val_seqs=29, test_seqs=5)
#     Epoch   1/150  train_loss=0.284508  val_loss=0.507030  patience=0/15 *
#     Epoch  11/150  train_loss=0.017032  val_loss=0.380887  patience=2/15
#     Epoch  21/150  train_loss=0.014204  val_loss=0.344431  patience=1/15
#     Epoch  31/150  train_loss=0.011981  val_loss=0.314262  patience=0/15 *
#     Epoch  41/150  train_loss=0.014868  val_loss=0.364871  patience=13/15
#     Epoch  43/150  train_loss=0.012591  val_loss=0.363869  patience=15/15
#     Early stopping at epoch 43
#   -> Predicted 5 days (stopped epoch 43, best_val=0.362045)
#
#   Step 15 (train_end=194, train_seqs=144, val_seqs=35, test_seqs=5)
#     Epoch   1/150  train_loss=0.335751  val_loss=0.397523  patience=0/15 *
#     Epoch  11/150  train_loss=0.027572  val_loss=0.266070  patience=5/15
#     Epoch  21/150  train_loss=0.021753  val_loss=0.251101  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 5 days (stopped epoch 21, best_val=0.249895)
#
#   Step 16 (train_end=199, train_seqs=148, val_seqs=36, test_seqs=5)
#     Epoch   1/150  train_loss=0.344060  val_loss=0.426335  patience=0/15 *
#     Epoch  11/150  train_loss=0.021581  val_loss=0.265604  patience=4/15
#     Epoch  21/150  train_loss=0.019701  val_loss=0.267894  patience=14/15
#     Epoch  22/150  train_loss=0.015616  val_loss=0.263234  patience=15/15
#     Early stopping at epoch 22
#   -> Predicted 5 days (stopped epoch 22, best_val=0.255966)
#
#   Step 17 (train_end=204, train_seqs=152, val_seqs=37, test_seqs=3)
#     Epoch   1/150  train_loss=0.375092  val_loss=0.455496  patience=0/15 *
#     Epoch  11/150  train_loss=0.023274  val_loss=0.271988  patience=1/15
#     Epoch  21/150  train_loss=0.019140  val_loss=0.273146  patience=1/15
#     Epoch  31/150  train_loss=0.017262  val_loss=0.252222  patience=0/15 *
#     Epoch  41/150  train_loss=0.014810  val_loss=0.258641  patience=3/15
#     Epoch  51/150  train_loss=0.012689  val_loss=0.260384  patience=13/15
#     Epoch  53/150  train_loss=0.019167  val_loss=0.260253  patience=15/15
#     Early stopping at epoch 53
#   -> Predicted 3 days (stopped epoch 53, best_val=0.252104)
#
#   AAPL LSTM Results:
#     NAIVE      RMSE=3.14  MAE=2.32  MAPE=1.04%  Dir_Acc=48.8%
#     LSTM       RMSE=23.85  MAE=22.88  MAPE=10.12%  Dir_Acc=48.8%
#
# ============================================================
#   LSTM Walk-Forward: AMZN
# ============================================================
#
#   Step 1 (train_end=124, train_seqs=88, val_seqs=21, test_seqs=5)
#     Epoch   1/150  train_loss=0.146323  val_loss=0.389881  patience=0/15 *
#     Epoch  11/150  train_loss=0.015370  val_loss=0.255296  patience=3/15
#     Epoch  21/150  train_loss=0.011593  val_loss=0.221655  patience=1/15
#     Epoch  31/150  train_loss=0.009246  val_loss=0.195680  patience=0/15 *
#     Epoch  41/150  train_loss=0.006548  val_loss=0.188369  patience=0/15 *
#     Epoch  51/150  train_loss=0.008909  val_loss=0.203427  patience=2/15
#     Epoch  61/150  train_loss=0.006294  val_loss=0.196003  patience=12/15
#     Epoch  64/150  train_loss=0.006315  val_loss=0.189040  patience=15/15
#     Early stopping at epoch 64
#   -> Predicted 5 days (stopped epoch 64, best_val=0.179747)
#
#   Step 2 (train_end=129, train_seqs=92, val_seqs=22, test_seqs=5)
#     Epoch  33/150  train_loss=0.010084  val_loss=0.104872  patience=15/15
#     Early stopping at epoch 33
#   -> Predicted 5 days (stopped epoch 33, best_val=0.103328)
#
#   Step 16 (train_end=199, train_seqs=148, val_seqs=36, test_seqs=5)
#     Epoch   1/150  train_loss=0.097824  val_loss=0.120403  patience=0/15 *
#     Epoch  11/150  train_loss=0.015058  val_loss=0.088901  patience=0/15 *
#     Epoch  21/150  train_loss=0.012264  val_loss=0.089924  patience=4/15
#     Epoch  31/150  train_loss=0.006459  val_loss=0.083880  patience=2/15
#     Epoch  41/150  train_loss=0.007677  val_loss=0.083212  patience=3/15
#     Epoch  51/150  train_loss=0.007509  val_loss=0.085523  patience=8/15
#     Epoch  58/150  train_loss=0.007299  val_loss=0.082488  patience=15/15
#     Early stopping at epoch 58
#   -> Predicted 5 days (stopped epoch 58, best_val=0.078195)
#
#   Step 17 (train_end=204, train_seqs=152, val_seqs=37, test_seqs=3)
#     Epoch   1/150  train_loss=0.121039  val_loss=0.165223  patience=0/15 *
#     Epoch  11/150  train_loss=0.018047  val_loss=0.112765  patience=0/15 *
#     Epoch  21/150  train_loss=0.015209  val_loss=0.121012  patience=4/15
#     Epoch  31/150  train_loss=0.009740  val_loss=0.110553  patience=14/15
#     Epoch  32/150  train_loss=0.008067  val_loss=0.112938  patience=15/15
#     Early stopping at epoch 32
#   -> Predicted 3 days (stopped epoch 32, best_val=0.106235)
#
#   AMZN LSTM Results:
#     NAIVE      RMSE=3.38  MAE=2.42  MAPE=1.34%  Dir_Acc=48.8%
#     LSTM       RMSE=10.47  MAE=8.72  MAPE=4.67%  Dir_Acc=51.2%
#
# ============================================================
#   LSTM Walk-Forward: GOOGL
# ============================================================
#
#   Step 1 (train_end=124, train_seqs=88, val_seqs=21, test_seqs=5)
#     Epoch   1/150  train_loss=0.237578  val_loss=0.489632  patience=0/15 *
#     Epoch  11/150  train_loss=0.021372  val_loss=0.406596  patience=0/15 *
#     Epoch  21/150  train_loss=0.015517  val_loss=0.391312  patience=5/15
#     Epoch  31/150  train_loss=0.014558  val_loss=0.383430  patience=0/15 *
#     Epoch  41/150  train_loss=0.013005  val_loss=0.388062  patience=10/15
#     Epoch  46/150  train_loss=0.018387  val_loss=0.390894  patience=15/15
#     Early stopping at epoch 46
#   -> Predicted 5 days (stopped epoch 46, best_val=0.383430)
#
#   Step 2 (train_end=129, train_seqs=92, val_seqs=22, test_seqs=5)
#     Epoch   1/150  train_loss=0.170234  val_loss=0.763409  patience=0/15 *
#     Epoch  11/150  train_loss=0.015482  val_loss=0.526898  patience=0/15 *
#     Epoch  21/150  train_loss=0.011824  val_loss=0.522595  patience=5/15
#     Epoch  31/150  train_loss=0.010121  val_loss=0.505529  patience=2/15
#     Epoch  41/150  train_loss=0.008581  val_loss=0.491269  patience=12/15
#     Epoch  44/150  train_loss=0.011606  val_loss=0.502017  patience=15/15
#     Early stopping at epoch 44
#   -> Predicted 5 days (stopped epoch 44, best_val=0.481681)
#
#   Step 3 (train_end=134, train_seqs=96, val_seqs=23, test_seqs=5)
#     Epoch  64/150  train_loss=0.008160  val_loss=0.114981  patience=15/15
#     Early stopping at epoch 64
#   -> Predicted 5 days (stopped epoch 64, best_val=0.112099)
#
#   Step 8 (train_end=159, train_seqs=116, val_seqs=28, test_seqs=5)
#     Epoch   1/150  train_loss=0.273946  val_loss=0.199725  patience=0/15 *
#     Epoch  11/150  train_loss=0.026570  val_loss=0.097711  patience=6/15
#     Epoch  20/150  train_loss=0.015951  val_loss=0.105236  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 5 days (stopped epoch 20, best_val=0.091593)
#
#   Step 9 (train_end=164, train_seqs=120, val_seqs=29, test_seqs=5)
#     Epoch   1/150  train_loss=0.295099  val_loss=0.050574  patience=0/15 *
#     Epoch  11/150  train_loss=0.023913  val_loss=0.038756  patience=1/15
#     Epoch  21/150  train_loss=0.016593  val_loss=0.028447  patience=9/15
#     Epoch  31/150  train_loss=0.012950  val_loss=0.029114  patience=4/15
#     Epoch  41/150  train_loss=0.011905  val_loss=0.027302  patience=14/15
#     Epoch  42/150  train_loss=0.013206  val_loss=0.027286  patience=15/15
#     Early stopping at epoch 42
#   -> Predicted 5 days (stopped epoch 42, best_val=0.025717)
#
#   Step 10 (train_end=169, train_seqs=124, val_seqs=30, test_seqs=5)
#     Epoch   1/150  train_loss=0.303243  val_loss=0.020156  patience=0/15 *
#     Epoch  11/150  train_loss=0.029742  val_loss=0.023250  patience=8/15
#     Epoch  18/150  train_loss=0.018550  val_loss=0.023790  patience=15/15
#     Early stopping at epoch 18
#   -> Predicted 5 days (stopped epoch 18, best_val=0.016906)
#
#   Step 11 (train_end=174, train_seqs=128, val_seqs=31, test_seqs=5)
#     Epoch   1/150  train_loss=0.274775  val_loss=0.042394  patience=0/15 *
#     Epoch  11/150  train_loss=0.019791  val_loss=0.070454  patience=10/15
#     Epoch  16/150  train_loss=0.017661  val_loss=0.067424  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.042394)
#
#   Step 12 (train_end=179, train_seqs=132, val_seqs=32, test_seqs=5)
#     Epoch   1/150  train_loss=0.234616  val_loss=0.031689  patience=0/15 *
#     Epoch  11/150  train_loss=0.019554  val_loss=0.044636  patience=10/15
#     Epoch  16/150  train_loss=0.017238  val_loss=0.044594  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.031689)
#
#   Step 13 (train_end=184, train_seqs=136, val_seqs=33, test_seqs=5)
#     Epoch   1/150  train_loss=0.255329  val_loss=0.043463  patience=0/15 *
#     Epoch  11/150  train_loss=0.021736  val_loss=0.048939  patience=7/15
#     Epoch  19/150  train_loss=0.021369  val_loss=0.047129  patience=15/15
#     Early stopping at epoch 19
#   -> Predicted 5 days (stopped epoch 19, best_val=0.037914)
#
#   Step 14 (train_end=189, train_seqs=140, val_seqs=34, test_seqs=5)
#     Epoch   1/150  train_loss=0.244473  val_loss=0.040388  patience=0/15 *
#     Epoch  11/150  train_loss=0.018056  val_loss=0.045741  patience=9/15
#     Epoch  17/150  train_loss=0.016719  val_loss=0.044919  patience=15/15
#     Early stopping at epoch 17
#   -> Predicted 5 days (stopped epoch 17, best_val=0.036210)
#
#   Step 15 (train_end=194, train_seqs=144, val_seqs=35, test_seqs=5)
#     Epoch   1/150  train_loss=0.254038  val_loss=0.041577  patience=0/15 *
#     Epoch  11/150  train_loss=0.019409  val_loss=0.058110  patience=9/15
#     Epoch  17/150  train_loss=0.023889  val_loss=0.057447  patience=15/15
#     Early stopping at epoch 17
#   -> Predicted 5 days (stopped epoch 17, best_val=0.037993)
#
#   Step 16 (train_end=199, train_seqs=148, val_seqs=36, test_seqs=5)
#     Epoch   1/150  train_loss=0.270135  val_loss=0.045550  patience=0/15 *
#     Epoch  11/150  train_loss=0.019316  val_loss=0.061443  patience=9/15
#     Epoch  17/150  train_loss=0.019706  val_loss=0.064493  patience=15/15
#     Early stopping at epoch 17
#   -> Predicted 5 days (stopped epoch 17, best_val=0.041396)
#
#   Step 17 (train_end=204, train_seqs=152, val_seqs=37, test_seqs=3)
#     Epoch   1/150  train_loss=0.242708  val_loss=0.029739  patience=0/15 *
#     Epoch  11/150  train_loss=0.022272  val_loss=0.029859  patience=6/15
#     Epoch  20/150  train_loss=0.015278  val_loss=0.029023  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 3 days (stopped epoch 20, best_val=0.022729)
#
#   GOOGL LSTM Results:
#     NAIVE      RMSE=2.59  MAE=1.93  MAPE=1.16%  Dir_Acc=56.1%
#     LSTM       RMSE=10.86  MAE=7.39  MAPE=4.27%  Dir_Acc=41.5%
#
# ============================================================
#   LSTM Walk-Forward: META
# ============================================================
#
#   Step 1 (train_end=124, train_seqs=88, val_seqs=21, test_seqs=5)
#     Epoch   1/150  train_loss=0.406662  val_loss=0.644363  patience=0/15 *
#     Epoch  11/150  train_loss=0.034407  val_loss=0.437367  patience=7/15
#     Epoch  19/150  train_loss=0.032576  val_loss=0.418824  patience=15/15
#     Early stopping at epoch 19
#   -> Predicted 5 days (stopped epoch 19, best_val=0.315679)
#
#   Step 2 (train_end=129, train_seqs=92, val_seqs=22, test_seqs=5)
#     Epoch   1/150  train_loss=0.125091  val_loss=0.287299  patience=0/15 *
#     Epoch  11/150  train_loss=0.025288  val_loss=0.242323  patience=8/15
#     Epoch  18/150  train_loss=0.018983  val_loss=0.236634  patience=15/15
#     Early stopping at epoch 18
#   -> Predicted 5 days (stopped epoch 18, best_val=0.229144)
#
#   Step 3 (train_end=134, train_seqs=96, val_seqs=23, test_seqs=5)
#     Epoch   1/150  train_loss=0.117283  val_loss=0.246929  patience=0/15 *
#     Epoch  11/150  train_loss=0.023960  val_loss=0.195982  patience=2/15
#     Epoch  21/150  train_loss=0.011020  val_loss=0.189371  patience=12/15
#     Epoch  24/150  train_loss=0.015497  val_loss=0.192349  patience=15/15
#     Early stopping at epoch 24
#   -> Predicted 5 days (stopped epoch 24, best_val=0.183722)
#
#   Step 4 (train_end=139, train_seqs=100, val_seqs=24, test_seqs=5)
#     Early stopping at epoch 107
#   -> Predicted 5 days (stopped epoch 107, best_val=0.142109)
#
#   Step 9 (train_end=164, train_seqs=120, val_seqs=29, test_seqs=5)
#     Epoch   1/150  train_loss=0.136657  val_loss=0.237555  patience=0/15 *
#     Epoch  11/150  train_loss=0.018796  val_loss=0.188585  patience=6/15
#     Epoch  20/150  train_loss=0.014407  val_loss=0.188009  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 5 days (stopped epoch 20, best_val=0.177688)
#
#   Step 10 (train_end=169, train_seqs=124, val_seqs=30, test_seqs=5)
#     Epoch   1/150  train_loss=0.243279  val_loss=0.456522  patience=0/15 *
#     Epoch  11/150  train_loss=0.031651  val_loss=0.241833  patience=1/15
#     Epoch  21/150  train_loss=0.016560  val_loss=0.231809  patience=9/15
#     Epoch  31/150  train_loss=0.014311  val_loss=0.227796  patience=5/15
#     Epoch  41/150  train_loss=0.011615  val_loss=0.223987  patience=2/15
#     Epoch  51/150  train_loss=0.012992  val_loss=0.218553  patience=12/15
#     Epoch  54/150  train_loss=0.011334  val_loss=0.218127  patience=15/15
#     Early stopping at epoch 54
#   -> Predicted 5 days (stopped epoch 54, best_val=0.216239)
#
#   Step 11 (train_end=174, train_seqs=128, val_seqs=31, test_seqs=5)
#     Epoch   1/150  train_loss=0.151103  val_loss=0.311285  patience=0/15 *
#     Epoch  11/150  train_loss=0.020501  val_loss=0.250966  patience=8/15
#     Epoch  18/150  train_loss=0.018530  val_loss=0.249283  patience=15/15
#     Early stopping at epoch 18
#   -> Predicted 5 days (stopped epoch 18, best_val=0.228336)
#
#   Step 12 (train_end=179, train_seqs=132, val_seqs=32, test_seqs=5)
#     Epoch   1/150  train_loss=0.225088  val_loss=0.556505  patience=0/15 *
#     Epoch  11/150  train_loss=0.029845  val_loss=0.368887  patience=6/15
#     Epoch  20/150  train_loss=0.016681  val_loss=0.360342  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 5 days (stopped epoch 20, best_val=0.347413)
#
#   Step 13 (train_end=184, train_seqs=136, val_seqs=33, test_seqs=5)
#     Epoch   1/150  train_loss=0.127521  val_loss=0.469117  patience=0/15 *
#     Epoch  11/150  train_loss=0.021752  val_loss=0.326189  patience=1/15
#     Epoch  21/150  train_loss=0.014138  val_loss=0.310890  patience=2/15
#     Epoch  31/150  train_loss=0.008527  val_loss=0.319582  patience=12/15
#     Epoch  34/150  train_loss=0.010354  val_loss=0.316269  patience=15/15
#     Early stopping at epoch 34
#   -> Predicted 5 days (stopped epoch 34, best_val=0.299206)
#
#   Step 14 (train_end=189, train_seqs=140, val_seqs=34, test_seqs=5)
#     Epoch   1/150  train_loss=0.092281  val_loss=0.413644  patience=0/15 *
#     Epoch  11/150  train_loss=0.016693  val_loss=0.300214  patience=1/15
#     Epoch  21/150  train_loss=0.010332  val_loss=0.284982  patience=11/15
#     Epoch  25/150  train_loss=0.009657  val_loss=0.284464  patience=15/15
#     Early stopping at epoch 25
#   -> Predicted 5 days (stopped epoch 25, best_val=0.280958)
#
#   Step 15 (train_end=194, train_seqs=144, val_seqs=35, test_seqs=5)
#     Epoch   1/150  train_loss=0.079461  val_loss=0.432191  patience=0/15 *
#     Epoch  11/150  train_loss=0.013490  val_loss=0.316813  patience=2/15
#     Epoch  21/150  train_loss=0.009411  val_loss=0.311351  patience=4/15
#     Epoch  31/150  train_loss=0.007252  val_loss=0.293274  patience=0/15 *
#     Epoch  41/150  train_loss=0.005590  val_loss=0.294352  patience=10/15
#     Epoch  51/150  train_loss=0.005978  val_loss=0.294233  patience=7/15
#     Epoch  59/150  train_loss=0.005885  val_loss=0.294975  patience=15/15
#     Early stopping at epoch 59
#   -> Predicted 5 days (stopped epoch 59, best_val=0.290172)
#
#   Step 16 (train_end=199, train_seqs=148, val_seqs=36, test_seqs=5)
#     Epoch   1/150  train_loss=0.060453  val_loss=0.417027  patience=0/15 *
#     Epoch  11/150  train_loss=0.009630  val_loss=0.330264  patience=4/15
#     Epoch  21/150  train_loss=0.008790  val_loss=0.323305  patience=7/15
#     Epoch  29/150  train_loss=0.007763  val_loss=0.321384  patience=15/15
#     Early stopping at epoch 29
#   -> Predicted 5 days (stopped epoch 29, best_val=0.317556)
#
#   Step 17 (train_end=204, train_seqs=152, val_seqs=37, test_seqs=3)
#     Epoch   1/150  train_loss=0.141140  val_loss=0.753536  patience=0/15 *
#     Epoch  11/150  train_loss=0.019804  val_loss=0.516373  patience=1/15
#     Epoch  21/150  train_loss=0.011647  val_loss=0.469430  patience=2/15
#     Epoch  31/150  train_loss=0.008401  val_loss=0.448122  patience=12/15
#     Epoch  34/150  train_loss=0.008932  val_loss=0.455495  patience=15/15
#     Early stopping at epoch 34
#   -> Predicted 3 days (stopped epoch 34, best_val=0.444424)
#
#   META LSTM Results:
#     NAIVE      RMSE=10.14  MAE=7.38  MAPE=1.42%  Dir_Acc=43.9%
#     LSTM       RMSE=69.10  MAE=62.09  MAPE=11.36%  Dir_Acc=48.8%
#
# ============================================================
#   LSTM Walk-Forward: MSFT
# ============================================================
#
#   Step 1 (train_end=124, train_seqs=88, val_seqs=21, test_seqs=5)
#     Epoch   1/150  train_loss=0.045149  val_loss=0.325093  patience=0/15 *
#     Epoch  11/150  train_loss=0.011133  val_loss=0.299400  patience=6/15
#     Epoch  20/150  train_loss=0.009226  val_loss=0.295600  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 5 days (stopped epoch 20, best_val=0.283885)
#
#   Step 2 (train_end=129, train_seqs=92, val_seqs=22, test_seqs=5)
#     Epoch   1/150  train_loss=0.035468  val_loss=0.543515  patience=0/15 *
#     Epoch  11/150  train_loss=0.008761  val_loss=0.541262  patience=9/15
#     Epoch  17/150  train_loss=0.008111  val_loss=0.547661  patience=15/15
#     Early stopping at epoch 17
#   -> Predicted 5 days (stopped epoch 17, best_val=0.528127)
#
#   Step 3 (train_end=134, train_seqs=96, val_seqs=23, test_seqs=5)
#     Epoch   1/150  train_loss=0.036913  val_loss=0.548550  patience=0/15 *
#     Epoch  11/150  train_loss=0.009081  val_loss=0.513552  patience=5/15
#     Early stopping at epoch 22
#   -> Predicted 5 days (stopped epoch 22, best_val=0.031475)
#
#   Step 16 (train_end=199, train_seqs=148, val_seqs=36, test_seqs=5)
#     Epoch   1/150  train_loss=0.114026  val_loss=0.042188  patience=0/15 *
#     Epoch  11/150  train_loss=0.017382  val_loss=0.034788  patience=5/15
#     Epoch  21/150  train_loss=0.011928  val_loss=0.035078  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 5 days (stopped epoch 21, best_val=0.033244)
#
#   Step 17 (train_end=204, train_seqs=152, val_seqs=37, test_seqs=3)
#     Epoch   1/150  train_loss=0.100156  val_loss=0.032814  patience=0/15 *
#     Epoch  11/150  train_loss=0.011833  val_loss=0.030270  patience=5/15
#     Epoch  21/150  train_loss=0.011043  val_loss=0.030573  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 3 days (stopped epoch 21, best_val=0.029052)
#
#   MSFT LSTM Results:
#     NAIVE      RMSE=5.07  MAE=3.94  MAPE=0.93%  Dir_Acc=54.9%
#     LSTM       RMSE=18.72  MAE=13.30  MAPE=3.05%  Dir_Acc=39.0%
#
# ============================================================
#   LSTM Walk-Forward: NVDA
# ============================================================
#
#   Step 1 (train_end=124, train_seqs=88, val_seqs=21, test_seqs=5)
#     Epoch   1/150  train_loss=0.063315  val_loss=0.835728  patience=0/15 *
#     Epoch  11/150  train_loss=0.008351  val_loss=0.629027  patience=0/15 *
#     Epoch  21/150  train_loss=0.005861  val_loss=0.640502  patience=10/15
#     Epoch  26/150  train_loss=0.004560  val_loss=0.634787  patience=15/15
#     Early stopping at epoch 26
#   -> Predicted 5 days (stopped epoch 26, best_val=0.629027)
#
#   Step 2 (train_end=129, train_seqs=92, val_seqs=22, test_seqs=5)
#     Epoch   1/150  train_loss=0.094945  val_loss=0.593185  patience=0/15 *
#     Epoch  11/150  train_loss=0.009351  val_loss=0.448591  patience=1/15
#     Epoch  21/150  train_loss=0.006985  val_loss=0.442535  patience=11/15
#     Epoch  25/150  train_loss=0.006100  val_loss=0.441876  patience=15/15
#     Early stopping at epoch 25
#   -> Predicted 5 days (stopped epoch 25, best_val=0.429947)
#
#   Step 3 (train_end=134, train_seqs=96, val_seqs=23, test_seqs=5)
#     Epoch   1/150  train_loss=0.091487  val_loss=0.849375  patience=0/15 *
#     Epoch  11/150  train_loss=0.008885  val_loss=0.580509  patience=2/15
#     Epoch  21/150  train_loss=0.006343  val_loss=0.543985  patience=12/15
#     Epoch  24/150  train_loss=0.005709  val_loss=0.544691  patience=15/15
#     Early stopping at epoch 24
#   -> Predicted 5 days (stopped epoch 24, best_val=0.543968)
#
#   Step 4 (train_end=139, train_seqs=100, val_seqs=24, test_seqs=5)
#     Epoch   1/150  train_loss=0.155681  val_loss=0.415242  patience=0/15 *
#     Epoch  11/150  train_loss=0.014351  val_loss=0.272998  patience=2/15
#     Epoch  21/150  train_loss=0.007815  val_loss=0.284375  patience=12/15
#     Epoch  24/150  train_loss=0.011275  val_loss=0.282624  patience=15/15
#     Early stopping at epoch 24
#   -> Predicted 5 days (stopped epoch 24, best_val=0.262596)
#
#   Step 5 (train_end=144, train_seqs=104, val_seqs=25, test_seqs=5)
#     Epoch   1/150  train_loss=0.165933  val_loss=0.619637  patience=0/15 *
#     Epoch  11/150  train_loss=0.012552  val_loss=0.325908  patience=5/15
#     Epoch  21/150  train_loss=0.008384  val_loss=0.339835  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 5 days (stopped epoch 21, best_val=0.291704)
#
#   Step 6 (train_end=149, train_seqs=108, val_seqs=26, test_seqs=5)
#     Epoch   1/150  train_loss=0.187361  val_loss=0.281931  patience=0/15 *
#     Epoch  11/150  train_loss=0.012979  val_loss=0.168191  patience=5/15
#     Epoch  21/150  train_loss=0.009496  val_loss=0.181212  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 5 days (stopped epoch 21, best_val=0.159435)
#
#   Step 7 (train_end=154, train_seqs=112, val_seqs=27, test_seqs=5)
#     Epoch   1/150  train_loss=0.176878  val_loss=0.287894  patience=0/15 *
#     Epoch  11/150  train_loss=0.014311  val_loss=0.171950  patience=5/15
#     Epoch  21/150  train_loss=0.009276  val_loss=0.165921  patience=2/15
#     Epoch  31/150  train_loss=0.007295  val_loss=0.162593  patience=12/15
#     Epoch  41/150  train_loss=0.009034  val_loss=0.162483  patience=4/15
#     Epoch  51/150  train_loss=0.007393  val_loss=0.160663  patience=14/15
#     Epoch  52/150  train_loss=0.008751  val_loss=0.160637  patience=15/15
#     Early stopping at epoch 52
#   -> Predicted 5 days (stopped epoch 52, best_val=0.159358)
#
#   Step 8 (train_end=159, train_seqs=116, val_seqs=28, test_seqs=5)
#     Epoch   1/150  train_loss=0.199814  val_loss=0.424795  patience=0/15 *
#     Epoch  11/150  train_loss=0.012686  val_loss=0.220121  patience=5/15
#     Epoch  21/150  train_loss=0.012252  val_loss=0.216088  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 5 days (stopped epoch 21, best_val=0.189588)
#
#   Step 9 (train_end=164, train_seqs=120, val_seqs=29, test_seqs=5)
#     Epoch   1/150  train_loss=0.215377  val_loss=0.390294  patience=0/15 *
#     Epoch  11/150  train_loss=0.013689  val_loss=0.220117  patience=1/15
#     Epoch  21/150  train_loss=0.009560  val_loss=0.207612  patience=4/15
#     Epoch  31/150  train_loss=0.009586  val_loss=0.201806  patience=5/15
#     Epoch  41/150  train_loss=0.009935  val_loss=0.195048  patience=6/15
#     Epoch  50/150  train_loss=0.008235  val_loss=0.192549  patience=15/15
#     Early stopping at epoch 50
#   -> Predicted 5 days (stopped epoch 50, best_val=0.191389)
#
#   Step 10 (train_end=169, train_seqs=124, val_seqs=30, test_seqs=5)
#     Epoch   1/150  train_loss=0.280047  val_loss=0.517866  patience=0/15 *
#     Epoch  11/150  train_loss=0.016596  val_loss=0.271772  patience=6/15
#     Epoch  20/150  train_loss=0.018603  val_loss=0.268855  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 5 days (stopped epoch 20, best_val=0.234168)
#
#   Step 11 (train_end=174, train_seqs=128, val_seqs=31, test_seqs=5)
#     Epoch  31/150  train_loss=0.007051  val_loss=0.163131  patience=2/15
#     Epoch  41/150  train_loss=0.008062  val_loss=0.164258  patience=12/15
#     Epoch  44/150  train_loss=0.007087  val_loss=0.161448  patience=15/15
#     Early stopping at epoch 44
#   -> Predicted 5 days (stopped epoch 44, best_val=0.152544)
#
#   Step 17 (train_end=204, train_seqs=152, val_seqs=37, test_seqs=3)
#     Epoch   1/150  train_loss=0.171455  val_loss=0.350071  patience=0/15 *
#     Epoch  11/150  train_loss=0.009731  val_loss=0.212970  patience=8/15
#     Epoch  18/150  train_loss=0.007730  val_loss=0.225469  patience=15/15
#     Early stopping at epoch 18
#   -> Predicted 3 days (stopped epoch 18, best_val=0.211709)
#
#   NVDA LSTM Results:
#     NAIVE      RMSE=4.35  MAE=3.42  MAPE=2.88%  Dir_Acc=41.5%
#     LSTM       RMSE=25.25  MAE=23.26  MAPE=18.58%  Dir_Acc=51.2%
#
# ============================================================
#   LSTM Walk-Forward: TSLA
# ============================================================
#
#   Step 1 (train_end=124, train_seqs=88, val_seqs=21, test_seqs=5)
#     Epoch   1/150  train_loss=0.146264  val_loss=0.061544  patience=0/15 *
#     Epoch  11/150  train_loss=0.014156  val_loss=0.033473  patience=5/15
#     Epoch  21/150  train_loss=0.012619  val_loss=0.032810  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 5 days (stopped epoch 21, best_val=0.031984)
#
#   Step 2 (train_end=129, train_seqs=92, val_seqs=22, test_seqs=5)
#     Epoch   1/150  train_loss=0.279010  val_loss=0.234658  patience=0/15 *
#     Epoch  11/150  train_loss=0.028339  val_loss=0.193419  patience=7/15
#     Epoch  19/150  train_loss=0.021617  val_loss=0.191651  patience=15/15
#     Early stopping at epoch 19
#   -> Predicted 5 days (stopped epoch 19, best_val=0.186634)
#
#   Step 3 (train_end=134, train_seqs=96, val_seqs=23, test_seqs=5)
#     Epoch   1/150  train_loss=0.189867  val_loss=0.321352  patience=0/15 *
#     Epoch  11/150  train_loss=0.021483  val_loss=0.386393  patience=10/15
#     Epoch  16/150  train_loss=0.017334  val_loss=0.382779  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.321352)
#
#   Step 4 (train_end=139, train_seqs=100, val_seqs=24, test_seqs=5)
#     Epoch   1/150  train_loss=0.067183  val_loss=0.594282  patience=0/15 *
#     Epoch  11/150  train_loss=0.019352  val_loss=0.646206  patience=10/15
#     Epoch  16/150  train_loss=0.015035  val_loss=0.643435  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.594282)
#
#   Step 5 (train_end=144, train_seqs=104, val_seqs=25, test_seqs=5)
#     Epoch   1/150  train_loss=0.091891  val_loss=0.526485  patience=0/15 *
#     Epoch  11/150  train_loss=0.017158  val_loss=0.582090  patience=10/15
#     Epoch  16/150  train_loss=0.012112  val_loss=0.579957  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.526485)
#
#   Step 6 (train_end=149, train_seqs=108, val_seqs=26, test_seqs=5)
#     Epoch   1/150  train_loss=0.236570  val_loss=0.287085  patience=0/15 *
#     Epoch  11/150  train_loss=0.034403  val_loss=0.421466  patience=10/15
#     Epoch  16/150  train_loss=0.024371  val_loss=0.418820  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.287085)
#
#   Step 7 (train_end=154, train_seqs=112, val_seqs=27, test_seqs=5)
#     Epoch   1/150  train_loss=0.101334  val_loss=0.485220  patience=0/15 *
#     Epoch  11/150  train_loss=0.015677  val_loss=0.444547  patience=1/15
#     Epoch  21/150  train_loss=0.009546  val_loss=0.434227  patience=6/15
#     Epoch  30/150  train_loss=0.009965  val_loss=0.439909  patience=15/15
#     Early stopping at epoch 30
#   -> Predicted 5 days (stopped epoch 30, best_val=0.428346)
#
#   Step 8 (train_end=159, train_seqs=116, val_seqs=28, test_seqs=5)
#     Epoch   1/150  train_loss=0.187531  val_loss=0.210487  patience=0/15 *
#     Epoch  11/150  train_loss=0.025165  val_loss=0.143773  patience=0/15 *
#     Epoch  21/150  train_loss=0.020280  val_loss=0.142848  patience=8/15
#     Epoch  28/150  train_loss=0.013242  val_loss=0.150481  patience=15/15
#     Early stopping at epoch 28
#   -> Predicted 5 days (stopped epoch 28, best_val=0.129911)
#
#   Step 9 (train_end=164, train_seqs=120, val_seqs=29, test_seqs=5)
#     Epoch   1/150  train_loss=0.153980  val_loss=0.174710  patience=0/15 *
#     Epoch  11/150  train_loss=0.016402  val_loss=0.123106  patience=5/15
#     Epoch  21/150  train_loss=0.011855  val_loss=0.126978  patience=15/15
#     Early stopping at epoch 21
#   -> Predicted 5 days (stopped epoch 21, best_val=0.112049)
#
#   Step 10 (train_end=169, train_seqs=124, val_seqs=30, test_seqs=5)
#     Epoch   1/150  train_loss=0.165056  val_loss=0.135385  patience=0/15 *
#     Epoch  11/150  train_loss=0.015889  val_loss=0.124873  patience=6/15
#     Epoch  20/150  train_loss=0.010561  val_loss=0.130576  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 5 days (stopped epoch 20, best_val=0.124641)
#
#   Step 11 (train_end=174, train_seqs=128, val_seqs=31, test_seqs=5)
#     Epoch   1/150  train_loss=0.167829  val_loss=0.138464  patience=0/15 *
#     Epoch  11/150  train_loss=0.026877  val_loss=0.164718  patience=10/15
#     Epoch  16/150  train_loss=0.019994  val_loss=0.168663  patience=15/15
#     Early stopping at epoch 16
#   -> Predicted 5 days (stopped epoch 16, best_val=0.138464)
#
#   Step 12 (train_end=179, train_seqs=132, val_seqs=32, test_seqs=5)
#     Epoch   1/150  train_loss=0.177372  val_loss=0.098168  patience=0/15 *
#     Epoch  11/150  train_loss=0.017645  val_loss=0.086471  patience=5/15
#     Epoch  21/150  train_loss=0.015164  val_loss=0.075991  patience=1/15
#     Epoch  31/150  train_loss=0.015271  val_loss=0.082694  patience=11/15
#     Epoch  35/150  train_loss=0.014352  val_loss=0.081191  patience=15/15
#     Early stopping at epoch 35
#   -> Predicted 5 days (stopped epoch 35, best_val=0.075356)
#
#   Step 13 (train_end=184, train_seqs=136, val_seqs=33, test_seqs=5)
#     Epoch   1/150  train_loss=0.242629  val_loss=0.115131  patience=0/15 *
#     Epoch  11/150  train_loss=0.028389  val_loss=0.113896  patience=6/15
#     Epoch  20/150  train_loss=0.018873  val_loss=0.099297  patience=15/15
#     Early stopping at epoch 20
#   -> Predicted 5 days (stopped epoch 20, best_val=0.094286)
#
#   Step 14 (train_end=189, train_seqs=140, val_seqs=34, test_seqs=5)
#     Epoch   1/150  train_loss=0.202469  val_loss=0.267347  patience=0/15 *
#     Epoch  11/150  train_loss=0.017537  val_loss=0.147056  patience=1/15
#     Epoch  21/150  train_loss=0.014450  val_loss=0.139722  patience=3/15
#     Epoch  31/150  train_loss=0.012021  val_loss=0.137887  patience=1/15
#     Epoch  41/150  train_loss=0.009786  val_loss=0.139868  patience=11/15
#     Epoch  45/150  train_loss=0.010210  val_loss=0.139264  patience=15/15
#     Early stopping at epoch 45
#   -> Predicted 5 days (stopped epoch 45, best_val=0.132228)
#
#   Step 15 (train_end=194, train_seqs=144, val_seqs=35, test_seqs=5)
#     Epoch   1/150  train_loss=0.183167  val_loss=0.354481  patience=0/15 *
#     Epoch  11/150  train_loss=0.020043  val_loss=0.195578  patience=2/15
#     Epoch  21/150  train_loss=0.013339  val_loss=0.176229  patience=3/15
#     Epoch  31/150  train_loss=0.015260  val_loss=0.171476  patience=9/15
#     Epoch  37/150  train_loss=0.012921  val_loss=0.167588  patience=15/15
#     Early stopping at epoch 37
#   -> Predicted 5 days (stopped epoch 37, best_val=0.155973)
#
#   Step 16 (train_end=199, train_seqs=148, val_seqs=36, test_seqs=5)
#     Epoch   1/150  train_loss=0.196839  val_loss=0.277207  patience=0/15 *
#     Epoch  11/150  train_loss=0.020211  val_loss=0.134227  patience=1/15
#     Epoch  21/150  train_loss=0.014621  val_loss=0.124107  patience=5/15
#     Epoch  31/150  train_loss=0.016758  val_loss=0.108025  patience=1/15
#     Epoch  41/150  train_loss=0.011840  val_loss=0.103877  patience=0/15 *
#     Epoch  51/150  train_loss=0.012793  val_loss=0.106318  patience=10/15
#     Epoch  56/150  train_loss=0.009138  val_loss=0.104931  patience=15/15
#     Early stopping at epoch 56
#   -> Predicted 5 days (stopped epoch 56, best_val=0.103877)
#
#   Step 17 (train_end=204, train_seqs=152, val_seqs=37, test_seqs=3)
#     Epoch   1/150  train_loss=0.157883  val_loss=0.473642  patience=0/15 *
#     Epoch  11/150  train_loss=0.015031  val_loss=0.223607  patience=1/15
#     Epoch  21/150  train_loss=0.015387  val_loss=0.217621  patience=1/15
#     Epoch  31/150  train_loss=0.011875  val_loss=0.206431  patience=11/15
#     Epoch  35/150  train_loss=0.008761  val_loss=0.219130  patience=15/15
#     Early stopping at epoch 35
#   -> Predicted 3 days (stopped epoch 35, best_val=0.191713)
#
#   TSLA LSTM Results:
#     NAIVE      RMSE=10.24  MAE=7.20  MAPE=3.13%  Dir_Acc=42.7%
#     LSTM       RMSE=34.18  MAE=29.37  MAPE=12.32%  Dir_Acc=48.8%
#
# ============================================================
# LSTM walk-forward completed for all tickers.
# GPU/MPS memory cleared.

# %% [markdown]
# ## 6. LSTM Standalone Results

# %%
lstm_rows = []

for ticker in tickers:
    r = lstm_results[ticker]
    for model_name, key in [('Naive', 'metrics_naive'), ('LSTM', 'metrics_lstm')]:
        lstm_rows.append({'Ticker': ticker, 'Model': model_name, **r[key]})

lstm_comparison_df = pd.DataFrame(lstm_rows)

print('=== LSTM Standalone vs Naive ===')
summary = lstm_comparison_df.groupby('Model')[['RMSE', 'MAE', 'MAPE', 'Dir_Acc']].mean().round(2)
summary = summary.reindex(['Naive', 'LSTM'])
display(summary)

print('\n=== Per-Ticker Breakdown ===')
print(f'{"Ticker":<8} {"Model":<12} {"RMSE":>8} {"MAE":>8} {"MAPE%":>8} {"Dir%":>8}')
print('-' * 54)
for ticker in tickers:
    for model_name, key in [('Naive', 'metrics_naive'), ('LSTM', 'metrics_lstm')]:
        m = lstm_results[ticker][key]
        print(f'{ticker:<8} {model_name:<12} {m["RMSE"]:>8.2f} {m["MAE"]:>8.2f} '
              f'{m["MAPE"]:>8.2f} {m["Dir_Acc"]:>8.1f}')
# Out:
# === LSTM Standalone vs Naive ===
#         RMSE    MAE  MAPE  Dir_Acc
# Model
# Naive   5.56   4.09   1.7    48.08
# LSTM   27.49  23.86   9.2    47.04
# === Per-Ticker Breakdown ===
# Ticker   Model            RMSE      MAE    MAPE%     Dir%
# ------------------------------------------------------
# AAPL     Naive            3.14     2.32     1.04     48.8
# AAPL     LSTM            23.85    22.88    10.12     48.8
# AMZN     Naive            3.38     2.42     1.34     48.8
# AMZN     LSTM            10.47     8.72     4.67     51.2
# GOOGL    Naive            2.59     1.93     1.16     56.1
# GOOGL    LSTM            10.86     7.39     4.27     41.5
# META     Naive           10.14     7.38     1.42     43.9
# META     LSTM            69.10    62.09    11.36     48.8
# MSFT     Naive            5.07     3.94     0.93     54.9
# MSFT     LSTM            18.72    13.30     3.05     39.0
# NVDA     Naive            4.35     3.42     2.88     41.5
# NVDA     LSTM            25.25    23.26    18.58     51.2
# TSLA     Naive           10.24     7.20     3.13     42.7
# TSLA     LSTM            34.18    29.37    12.32     48.8

# %%
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
metrics = ['RMSE', 'MAE', 'MAPE', 'Dir_Acc']
titles = ['RMSE (lower is better)', 'MAE (lower is better)',
          'MAPE % (lower is better)', 'Directional Accuracy % (higher is better)']

for ax, metric, title in zip(axes, metrics, titles):
    pivot = lstm_comparison_df.pivot(index='Ticker', columns='Model', values=metric)
    pivot = pivot[['Naive', 'LSTM']]
    pivot.plot(kind='bar', ax=ax, edgecolor='white', alpha=0.85)
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_xlabel('Ticker')
    ax.set_ylabel(metric)
    ax.tick_params(axis='x', rotation=0)
    ax.legend(fontsize=8)

plt.suptitle('LSTM Standalone vs Naive Baseline', fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Predicted vs Actual -- LSTM Standalone

# %%
fig, axes = plt.subplots(2, 4, figsize=(24, 10))
axes = axes.flatten()

for i, ticker in enumerate(tickers):
    r = lstm_results[ticker]
    dates = r['dates']

    axes[i].plot(dates, r['actuals'], label='Actual', linewidth=1.8, color='black')
    axes[i].plot(dates, r['naive'], label='Naive', linewidth=1.0, color='gray', alpha=0.7, linestyle='--')
    axes[i].plot(dates, r['lstm'], label='LSTM', linewidth=1.2, color='coral', alpha=0.9)

    axes[i].set_title(ticker, fontsize=13, fontweight='bold')
    axes[i].tick_params(axis='x', rotation=45, labelsize=8)
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Close ($)')
    if i == 0:
        axes[i].legend(fontsize=8)

axes[-1].set_visible(False)
fig.suptitle('Predicted vs Actual -- LSTM Standalone', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Save LSTM Predictions for Ensemble Notebook
#
# Export the walk-forward LSTM predictions so the ensemble notebook can load them without re-training.

# %%
import pickle

save_data = {
    'lstm_results': lstm_results,
    'tickers': tickers,
    'all_feature_cols': all_feature_cols,
    'price_feature_cols': price_feature_cols,
    'nlp_feature_cols': nlp_feature_cols,
    'config': {
        'INITIAL_TRAIN_PCT': TRAIN_PCT,
        'STEP_SIZE': STEP_SIZE,
        'LOOKBACK': LOOKBACK,
    }
}

with open('lstm_predictions.pkl', 'wb') as f:
    pickle.dump(save_data, f)

print(f'Saved lstm_predictions.pkl')
print(f'  Tickers: {tickers}')
for ticker in tickers:
    r = lstm_results[ticker]
    print(f'  {ticker}: {len(r["lstm"])} predictions')
# Out:
# Saved lstm_predictions.pkl
#   Tickers: ['AAPL', 'AMZN', 'GOOGL', 'META', 'MSFT', 'NVDA', 'TSLA']
#   AAPL: 83 predictions
#   AMZN: 83 predictions
#   GOOGL: 83 predictions
#   META: 83 predictions
#   MSFT: 83 predictions
#   NVDA: 83 predictions
#   TSLA: 83 predictions

# %% [markdown]
# ## Conclusions
#
# ### LSTM Standalone Performance
#
# The LSTM model was evaluated independently against the naive baseline (previous day's close) using walk-forward validation across 7 tickers.
#
# **Key observations to verify from the results above (Section 6):**
#
# - LSTM RMSE and MAE compared to the naive baseline per ticker
# - Whether directional accuracy improves with the sequence-based approach
# - Which tickers benefit most from the LSTM's temporal pattern learning
#
# ### Architecture & Techniques
#
# | Component | Choice | Rationale |
# |-----------|--------|-----------|
# | Layers | 2-layer LSTM, 64 hidden units | Small to avoid overfitting on ~200 samples/ticker |
# | Initialization | Orthogonal (first layer) | From SOTA Notebook 5, helps gradient flow |
# | Regularization | Dropout 0.2 + early stopping (patience=15) | Prevents overfitting on small data |
# | Augmentation | Jitter (std=0.01) | From SOTA Notebook 4, synthetic training diversity |
# | Scaling | Dual MinMaxScalers (-1, 1) | Separate scalers for features and target |
# | Lookback | 15 days | Balance between context and sample count |
# | Validation | Walk-forward, expanding window (`TRAIN_PCT` init), 5-day step | Time-series aware, no look-ahead bias |
#
# ### Next Steps
#
# LSTM predictions have been saved to `lstm_predictions.pkl`. The **ensemble notebook** will:
# 1. Load these LSTM predictions
# 2. Run XGBoost walk-forward on the same splits
# 3. Build a weighted ensemble (LSTM + XGBoost)
# 4. Compare all models and optimize ensemble weights
